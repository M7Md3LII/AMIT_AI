# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data=pd.read_csv('bank-additional-full.csv')

# %%
data
# Out:
#       age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0      56;"housemaid";"married";"basic.4y";"no";"no";...
# 1      57;"services";"married";"high.school";"unknown...
# 2      37;"services";"married";"high.school";"no";"ye...
# 3      40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4      56;"services";"married";"high.school";"no";"no...
# ...                                                  ...
# 41183  73;"retired";"married";"professional.course";"...
# 41184  46;"blue-collar";"married";"professional.cours...
# 41185  56;"retired";"married";"university.degree";"no...
# 41186  44;"technician";"married";"professional.course...
# 41187  74;"retired";"married";"professional.course";"...
#
# [41188 rows x 1 columns]

# %%
data= pd.read_csv('bank-additional-full.csv',sep = ';')

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data['y']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41183    yes
# 41184     no
# 41185     no
# 41186    yes
# 41187     no
# Name: y, Length: 41188, dtype: object

# %%
data['y'].value_counts()
 #Imbalanced DataSet
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis.

# %%
#saving the target variable 
target = data['y']

# %%
#Exploratory Data Analysis
#for numerical variable by Boxplot
#finding outlaier
num_var = ["age","duration","campaign", "pdays", "previous","emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"]

for i in num_var:
  sns.boxplot(x = target,y = i,data = data)
  plt.show();

# %%
#finding the correlation among the variables
#Here features is highly correlated like 'emp.var.rate' and 'cons.cont.idx' and many more
plt.figure(figsize=(25,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
cat_var=[i for i in df.columns if i not in num_var]
target = target.values


#Exploratory Data Analysis for categorical variable

for i in cat_var:
    plt.figure(figsize=(30,5))
    sns.countplot(x=i, hue=y1, data=df)
    plt.show()

# %%
data_1 = pd.get_dummies(data)

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 65 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            41188 non-null  int64
#  1   duration                       41188 non-null  int64
#  2   campaign                       41188 non-null  int64
#  3   pdays                          41188 non-null  int64
#  4   previous                       41188 non-null  int64
#  5   emp.var.rate                   41188 non-null  float64
#  6   cons.price.idx                 41188 non-null  float64
#  7   cons.conf.idx                  41188 non-null  float64
#  8   euribor3m                      41188 non-null  float64
#  9   nr.employed                    41188 non-null  float64
#  10  job_admin.                     41188 non-null  uint8
#  11  job_blue-collar                41188 non-null  uint8
# ...

# %%
sns.regplot(x="emp.var.rate", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='emp.var.rate', ylabel='y_yes'>

# %%
sns.regplot(x="nr.employed", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='nr.employed', ylabel='y_yes'>

# %%
sns.regplot(x="age", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='y_yes'>

# %%
sns.regplot(x="age", y="y_yes", order=3, data=data_1, truncate=True);

# %%
sns.regplot(x="campaign", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='campaign', ylabel='y_yes'>

# %%
sns.regplot(x="cons.conf.idx", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='cons.conf.idx', ylabel='y_yes'>

# %%
sns.regplot(x="duration", y="y_yes", order=1, data=data_1, truncate=True);

# %%
sns.regplot(x="contact_telephone", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='contact_telephone', ylabel='y_yes'>

# %%
sns.regplot(x="month_sep", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='month_sep', ylabel='y_yes'>

# %%
sns.regplot(x="poutcome_nonexistent", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='poutcome_nonexistent', ylabel='y_yes'>

# %%
sns.regplot(x="education_unknown", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='education_unknown', ylabel='y_yes'>

# %%
sns.regplot(x="euribor3m", y="y_yes", order=1, data=data_1, truncate=True)
# Out:
# <AxesSubplot:xlabel='euribor3m', ylabel='y_yes'>

# %%
#Above plot shows that any campaign after 20 is useless. Hence no customer must be approached more than 20 times.

# %%
data_1.loc[((data_1)['campaign'] >15) & (data_1['y_yes']==1)]
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 3219    39       651        23    999         0           1.1          93.994
# 10162   44       541        17    999         0           1.4          94.465
# 17284   59      1448        17    999         0           1.4          93.918
# 17655   50      1076        17    999         0           1.4          93.918
# 29980   31       207        17    999         0          -1.8          93.075
#
#        cons.conf.idx  euribor3m  nr.employed  ...  day_of_week_fri  \
# 3219           -36.4      4.860       5191.0  ...                0
# 10162          -41.8      4.958       5228.1  ...                0
# 17284          -42.7      4.962       5228.1  ...                1
# 17655          -42.7      4.962       5228.1  ...                0
# 29980          -47.1      1.405       5099.1  ...                0
#
#        day_of_week_mon  day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# ...

# %%
#Keeping aside the target feature and drop it here
y_yes1 = data_1['y_yes']
y_no1 = data_1['y_no']
data_1.drop('y_yes',axis = 1,inplace = True)
data_1.drop('y_no',axis = 1,inplace = True)

# %% [markdown]
# # Model Building.

# %%
#Using RandomForestClassifier for the binary classification Problem.

from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=350,
                                random_state=0)
forest.fit(data_1,y1)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# %%
# Print the feature ranking on the basis of RandomForestClassifier

print("Feature ranking:")
for f in range(data_1.shape[1]):
    print("%d. %s: %f " % (f + 1, data_1.columns[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. duration: 0.282091
# 2. euribor3m: 0.094536
# 3. age: 0.079953
# 4. nr.employed: 0.049350
# 5. campaign: 0.039866
# 6. pdays: 0.030400
# 7. cons.conf.idx: 0.026077
# 8. cons.price.idx: 0.023676
# 9. emp.var.rate: 0.019739
# 10. poutcome_success: 0.019149
# 11. housing_no: 0.013315
# 12. housing_yes: 0.013118
# 13. job_admin.: 0.012119
# 14. education_university.degree: 0.011966
# 15. previous: 0.011869
# 16. marital_married: 0.011642
# 17. day_of_week_mon: 0.010883
# 18. education_high.school: 0.010787
# 19. day_of_week_thu: 0.010758
# 20. marital_single: 0.010609
# 21. day_of_week_wed: 0.010422
# 22. day_of_week_tue: 0.010376
# 23. day_of_week_fri: 0.009896
# 24. job_technician: 0.009840
# 25. loan_no: 0.009253
# 26. loan_yes: 0.008882
# 27. education_professional.course: 0.008338
# 28. job_blue-collar: 0.007990
# 29. poutcome_nonexistent: 0.007754
# 30. education_basic.9y: 0.007560
# 31. poutcome_failure: 0.007215
# 32. marital_divorced: 0.007115
# ...

# %%
#Plot the feature importances of the forest model classifier

plt.figure()
plt.figure(figsize=(15,10))
plt.title("Feature importances")
plt.bar(range(data_1.shape[1]), importances[indices],color="b", yerr=std[indices], align="center")
plt.xticks(range(data_1.shape[1]), indices)
plt.xlim([-1, data_1.shape[1]])
plt.show();

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

#split dataset into train and test data according to stratification..
X_train, X_test, y_train, y_test = train_test_split(data_1, y1, test_size=0.2, random_state=1, stratify=y1)

# %%
from sklearn.metrics import accuracy_score

for i in range(10,300,10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)

    print(accuracy_score(knn.predict(X_test),y_test))
# Out:
# 0.9098082058752124
# 0.9134498664724447
# 0.911750424860403
# 0.9141781985918912
# 0.9136926438455936
# 0.9136926438455936
# 0.9139354212187424
# 0.9139354212187424
# 0.9139354212187424
# 0.9136926438455936
# 0.9135712551590192
# 0.9133284777858703
# 0.9132070890992959
# 0.9134498664724447
# 0.9134498664724447
# 0.9130857004127215
# 0.9133284777858703
# 0.9129643117261471
# 0.9127215343529983
# 0.9132070890992959
# 0.9123573682932751
# 0.9121145909201263
# 0.9119932022335518
# 0.9126001456664239
# 0.9122359796067007
# 0.9127215343529983
# 0.9123573682932751
# 0.9124787569798495
# 0.9121145909201263

# %%
#here maximum accuracy at k = 40
#Accuracy Score = 91.4%

# %% [markdown]
# # Optimization.

# %%
#collecting the Target variable data in a single DataFrame
t = pd.DataFrame()
t['y_yes'] = y_yes1
t['y_no'] = y_no1
t.head()
# Out:
#    y_yes  y_no
# 0      0     1
# 1      0     1
# 2      0     1
# 3      0     1
# 4      0     1

# %%
print("For age upto 30")
print("Nth Call \t Efficiency")
for i in range(1,30):
    num = float(data_1[(data_1['age'] <= 30) & (data_1['campaign']==i) & (t['y_yes']==1)].shape[0])
    den = 1+float(data_1[(data_1['age'] <= 30) & (data_1['campaign'] >= i)].shape[0])
    print (str((i))+" \t\t "+str(num/den))
# Out:
# For age upto 30
# Nth Call 	 Efficiency
# 1 		 0.07502708559046588
# 2 		 0.07100309745055992
# 3 		 0.06274509803921569
# 4 		 0.04447739065974796
# 5 		 0.03882352941176471
# 6 		 0.02058319039451115
# 7 		 0.030805687203791468
# 8 		 0.006493506493506494
# 9 		 0.012875536480686695
# 10 		 0.005376344086021506
# 11 		 0.013888888888888888
# 12 		 0.0
# 13 		 0.010869565217391304
# 14 		 0.0
# 15 		 0.014705882352941176
# 16 		 0.0
# 17 		 0.0
# 18 		 0.0
# 19 		 0.0
# 20 		 0.0
# 21 		 0.0
# 22 		 0.0
# 23 		 0.0
# 24 		 0.0
# 25 		 0.0
# 26 		 0.0
# 27 		 0.0
# 28 		 0.0
# 29 		 0.0

# %%
print("For age between 30-40")
print("Nth Call \t Efficiency")
for i in range(1,30):
    num = float(data_1[(data_1['age'] <= 40) & (data_1['age'] > 30) & (data_1['campaign']==i) & (t['y_yes']==1)].shape[0])
    den = 1+float(df[(data['age'] <= 40) & (data['age'] > 30) & (data['campaign'] >= i)].shape[0])
    print (str((i))+" \t\t "+str(num/den))
# Out:
# For age between 30-40
# Nth Call 	 Efficiency
# 1 		 6.4
# 2 		 7.142857142857143
# 3 		 13.733333333333333
# 4 		 21.0
# 5 		 20.0
# 6 		 32.0
# 7 		 7.0
# 8 		 6.0
# 9 		 6.0
# 10 		 5.0
# 11 		 5.0
# 12 		 2.0
# 13 		 2.0
# 14 		 0.0
# 15 		 0.0
# 16 		 0.0
# 17 		 1.0
# 18 		 0.0
# 19 		 0.0
# 20 		 0.0
# 21 		 0.0
# 22 		 0.0
# 23 		 1.0
# 24 		 0.0
# 25 		 0.0
# 26 		 0.0
# 27 		 0.0
# 28 		 0.0
# 29 		 0.0
# <ipython-input-349-5950f4448835>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   den = 1+float(df[(data['age'] <= 40) & (data['age'] > 30) & (data['campaign'] >= i)].shape[0])
# <ipython-input-349-5950f4448835>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   den = 1+float(df[(data['age'] <= 40) & (data['age'] > 30) & (data['campaign'] >= i)].shape[0])
# <ipython-input-349-5950f4448835>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
#We can see the trend from the regplot between age and target feature with order 3.
# Hence I have choosen the Efficiency of phone call After 6th number of call is get very low.

# %%
# Calculate how many calls were made in total
total_calls = sum(data_1['campaign'])
print(total_calls)
# Out:
# 105754

# %%
# Calculate how many calls were made after the 6th call
extra_calls = sum(data_1[data_1['campaign']>6]['campaign']) - 6*df1[df1['campaign']>6].shape[0]
print(extra_calls)
# Out:
# 12040

# %%
# Calculate reduction in marketing cost
reduction=100*extra_calls/total_calls
print(reduction)
# Out:
# 11.384912154622993

# %%
total_sales=float(t[t['y_yes']==1].shape[0])
print(total_sales)
# Out:
# 4640.0

# %%
less_costly_sales=float(data_1[(data_1['campaign'] <= 6) & (t['y_yes']==1)].shape[0])
print(less_costly_sales)
# Out:
# 4529.0

# %%
sales_percent=100*less_costly_sales/total_sales
print(sales_percent)
# Out:
# 97.60775862068965

# %% [markdown]
# # Findings.
#
# ## Here It is observed that the Accurecy of the KNN Classifier model is approx** 91.4%** . I can say that the model performed the good and it could be better by using oversampling method because of imbalanced classified DataSet.
#
# ## Here a reduction in Marketing cost about 11.4% in marketing cost can be achieved while maintaining 97.6% sales if any person is called a maximum of 6 times.
